# %%
# This file is used to run all the notebooks in order.

# %run ./notebooks/data_collection.ipynb

# %run ./notebooks/exploratory_data_analysis.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /var/folders/5k/bl_qtkt52y9_ktf36t8h55lh0000gn/T/ipykernel_37983/2493842976.py:3
#       1 if __name__ == "__main__":
#       2     # Example run on default two categories
# ----> 3     run_for_categories(categories=VALID_CATEGORIES)
#
# File /var/folders/5k/bl_qtkt52y9_ktf36t8h55lh0000gn/T/ipykernel_37983/2286084723.py:17, in run_for_categories(categories, run_core0, run_core5)
#      15 if run_core0:
#      16     try:
# ---> 17         df0 = load_core_dataset('0core', cat)
#      18         run_eda_core0(df0, name_suffix=f" | {cat}")
#      19         # free memory for df0
#
# File /var/folders/5k/bl_qtkt52y9_ktf36t8h55lh0000gn/T/ipykernel_37983/1858545722.py:56, in load_core_dataset(core, category, splits, downcast, drop_duplicates)
#      54 try:
#      55     logger.log_info(f"[Loader] Reading: {path.name}")
# ...
