# %% [markdown]
# # Exploratory Data Analysis (EDA) — Quick Guide
#
# **Part 1 · Overview**
# EDA is the first pass to understand your dataset’s shape and quality: sizes, types, missingness, basic statistics, distributions, correlations, and outliers. Good EDA reveals patterns, detects data issues early, and informs the next modeling or business steps.
#
# **Part 2 · Notebook Structure**
# - **Setup**: imports, options, helper utils.
# - **Load Data**: read raw files/tables and basic integrity checks.
# - **Audit & Clean**: dtypes, duplicates, missing values, simple fixes.
# - **Univariate**: summaries and distributions for key fields.
# - **Bivariate/Multivariate**: relationships (corr, cross‑tabs, scatter).
# - **Feature Notes**: quick ideas for derived columns (optional).
# - **Visuals**: compact plots for the above steps.
# - **Outputs**: save cleaned data/artifacts for reuse.
#
# **Part 3 · EDA Process**
# 1) Define questions and key metrics.
# 2) Inspect schema and basic stats.
# 3) Profile missingness, duplicates, and anomalies.
# 4) Explore distributions and relationships.
# 5) Document findings and data issues.
# 6) Save cleaned datasets and a short summary/report.

# %% [markdown]
# ### Task: Import libraries and external modules

# %%
import sys, gc
from pathlib import Path
from polars.selectors import numeric
import matplotlib.pyplot as plt, seaborn as sns, polars as pl, numpy as np

sys.path.insert(0, str(Path("../utilities").resolve()))
from logger import Logger
from configurations import Configurations

sns.set_style("whitegrid")

# %% [markdown]
# ### Task: Configurations

# %%
logger = Logger("exploratory_data_analysis", Configurations.LOG_PATH)
PROCESSED_DIR = Path(Configurations.DATA_PROCESSED_PATH)
VALID_CORES, VALID_CATEGORIES, VALID_SPLITS, VALID_COLS = Configurations.CORES, Configurations.CATEGORIES, Configurations.SPLITS_EDA, Configurations.COLUMNS

for k, v in {"VALID_CORES": VALID_CORES, "VALID_CATEGORIES": VALID_CATEGORIES, "VALID_SPLITS": VALID_SPLITS, "VALID_COLS": VALID_COLS}.items():
    logger.log_info(f"{k} = {v}")
# Out:
# 2025-11-03 15:35:12,387 - INFO - VALID_CORES = ['5core']
# 2025-11-03 15:35:12,396 - INFO - VALID_CATEGORIES = ['Electronics', 'Beauty_and_Personal_Care', 'Sports_and_Outdoors']
# 2025-11-03 15:35:12,447 - INFO - VALID_SPLITS = ['train']
# 2025-11-03 15:35:12,448 - INFO - VALID_COLS = ['user_id', 'parent_asin', 'rating', 'timestamp']

# %% [markdown]
# ### Task: Grouped EDA functions with interpretation

# %% [markdown]
# #### Load_helpers

# %%
def _file_path(core: str, category: str, split: str) -> Path:
    dev_sample_size = Configurations.DEV_SAMPLE_SIZE

    if dev_sample_size != 'full':
        sample_sizes = Configurations.SAMPLE_SIZES
        for size_name in sample_sizes.keys():
            if size_name == dev_sample_size:
             return PROCESSED_DIR / f"{category.replace('/', '-')}.{core}.{split}.{size_name}.parquet"
    else:
        return PROCESSED_DIR / f"{category.replace('/', '-')}.{core}.{split}.parquet"
       
def _read_split_file(path: Path, split: str, downcast: bool = False) -> pl.DataFrame:
    df = pl.read_parquet(path, columns=VALID_COLS)
    missing = [c for c in VALID_COLS if c not in df.columns]
    if missing:
        raise ValueError(f"Missing columns {missing} in {path.name}")
    if downcast:
        cols = []
        if "rating" in df.columns:
            cols.append(pl.col("rating").cast(pl.Int16))
        if "timestamp" in df.columns:
            cols.append(
                pl.col("timestamp")
                .cast(pl.Int64)
                .map_elements(lambda x: x // 1000 if x > 10**12 else x, return_dtype=pl.Int64)
            )
        if "user_id" in df.columns:
            cols.append(pl.col("user_id").cast(pl.Categorical))
        if "parent_asin" in df.columns:
            cols.append(pl.col("parent_asin").cast(pl.Categorical))
        if cols:
            df = df.with_columns(*cols)
    return df

def load_core_dataset(core: str, category: str, splits: tuple = VALID_SPLITS, downcast: bool = False, drop_duplicates: bool = False) -> pl.DataFrame:
    core = core.lower().strip()
    if core not in VALID_CORES:
        raise ValueError(f"Invalid core '{core}'. Must be one of: {VALID_CORES}")

    logger.log_info(f"[Loader] core={core}, category={category}, splits={splits}")
    frames = []
    for sp in splits:
        path = _file_path(core, category, sp)
        if not path.exists() or path.stat().st_size == 0:
            logger.log_warning(f"[Loader] Missing file: {path.name} (skip {sp})")
            continue
        try:
            logger.log_info(f"[Loader] Reading: {path.name}")
            df_sp = _read_split_file(path, sp, downcast)
            frames.append(df_sp)
            logger.log_info(f"[Loader] Loaded {sp}: rows={df_sp.height}, cols={df_sp.width}")
        except Exception as e:
            logger.log_exception(f"[Loader] Failed reading {path.name}: {e}")

    if not frames:
        raise FileNotFoundError(f"No valid splits for core={core}, category={category}")

    df = pl.concat(frames)
    if drop_duplicates:
        before = df.height
        df = df.unique(subset=["user_id", "parent_asin", "timestamp", "rating"])
        logger.log_info(f"[Loader] Dropped duplicates: {before - df.height}")

    n_users, n_items = df.select(pl.col("user_id").n_unique(), pl.col("parent_asin").n_unique()).row(0)
    density = df.height / (max(n_users, 1) * max(n_items, 1))
    logger.log_info(f"[Loader] Done core={core}, category={category} | rows={df.height}, cols={df.width} | users={n_users} | items={n_items} | density={density:.6f}")
    return df

# %% [markdown]
# #### eda_basic

# %%
def eda_basic(df: pl.DataFrame, name: str = "dataset"):
    # core counts
    n_users, n_items = df.select(pl.col("user_id").n_unique(), pl.col("parent_asin").n_unique()).row(0)
    n_ratings = df.height
    density = n_ratings / (max(n_users, 1) * max(n_items, 1))
    sparsity = 1 - density
    
    # Calculate average interactions
    avg_items_per_user = n_ratings / max(n_users, 1)
    avg_users_per_item = n_ratings / max(n_items, 1)
    
    logger.log_info(f"[Basic] {name} | users={n_users:,} | items={n_items:,} | ratings={n_ratings:,}")
    logger.log_info(f"[Basic] {name} | density={density:.6f} | sparsity={sparsity:.6%}")
    logger.log_info(f"[Basic] {name} | avg_items/user={avg_items_per_user:.2f} | avg_users/item={avg_users_per_item:.2f}")

    # types & missing
    types = "\n".join(f"{c}: {t}" for c, t in zip(df.columns, df.dtypes))
    logger.log_info(f"[Basic][Data types]\n{types}")
    logger.log_info(f"[Basic][Missing values]\n{df.null_count()}")

    # duplicates & numeric summary
    dup_count = df.height - df.unique().height
    logger.log_info(f"[Basic][Duplicate rows] {dup_count}")
    if dup_count:
        try:
            num_stats = df.select(pl.col(numeric())).describe()
            logger.log_info(f"[Basic][Numeric stats]\n{num_stats}")
        except Exception as e:
            logger.log_exception(f"[Basic] Failed numeric describe: {e}")

    # ========================================================================
    # SPARSITY & INTERACTION METRICS VISUALIZATION
    # ========================================================================
    
    fig, axes = plt.subplots(1, 3, figsize=(16, 5))
    
    # Plot 1: Sparsity vs Density
    metrics = ['Density', 'Sparsity']
    values = [density * 100, sparsity * 100]
    colors = ['#2ECC71', '#E74C3C']
    
    axes[0].bar(metrics, values, color=colors, alpha=0.7)
    axes[0].set_ylabel('Percentage (%)', fontsize=11)
    axes[0].set_title('Matrix Density vs Sparsity', fontsize=12, fontweight='bold')
    axes[0].set_ylim(0, 100)
    
    # Add value labels
    for i, (metric, value) in enumerate(zip(metrics, values)):
        axes[0].text(i, value/2, f'{value:.4f}%', 
                    ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    axes[0].grid(axis='y', alpha=0.3)
    
    # Plot 2: Average Interactions
    interaction_metrics = ['Avg Items\nper User', 'Avg Users\nper Item']
    interaction_values = [avg_items_per_user, avg_users_per_item]
    colors_2 = ['#3498DB', '#9B59B6']
    
    bars = axes[1].bar(interaction_metrics, interaction_values, color=colors_2, alpha=0.7)
    axes[1].set_ylabel('Count', fontsize=11)
    axes[1].set_title('Average Interactions', fontsize=12, fontweight='bold')
    axes[1].grid(axis='y', alpha=0.3)
    
    # Add value labels
    for bar, value in zip(bars, interaction_values):
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2., height/2,
                    f'{value:.2f}',
                    ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    # Plot 3: Summary Statistics Table
    axes[2].axis('off')
    
    # Create summary table data
    table_data = [
        ['Metric', 'Value'],
        ['Total Users', f'{n_users:,}'],
        ['Total Ratings', f'{n_ratings:,}'],
        ['Density', f'{density:.6f}'],
        ['Sparsity', f'{sparsity:.4%}'],
        ['Items/User', f'{avg_items_per_user:.2f}'],
        ['Users/Item', f'{avg_users_per_item:.2f}'],
    ]
    
    table = axes[2].table(
        cellText=table_data,
        cellLoc='left',
        loc='center',
        colWidths=[0.5, 0.5]
    )
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1, 2.2)
    
    # Style header row
    table[(0, 0)].set_facecolor('#34495E')
    table[(0, 1)].set_facecolor('#34495E')
    table[(0, 0)].set_text_props(weight='bold', color='white')
    table[(0, 1)].set_text_props(weight='bold', color='white')
    
    # Alternate row colors
    for i in range(1, len(table_data)):
        if i % 2 == 0:
            table[(i, 0)].set_facecolor('#ECF0F1')
            table[(i, 1)].set_facecolor('#ECF0F1')
    
    # Highlight sparsity row
    table[(6, 0)].set_facecolor('#FADBD8')
    table[(6, 1)].set_facecolor('#FADBD8')
    table[(6, 0)].set_text_props(weight='bold')
    table[(6, 1)].set_text_props(weight='bold')
    
    plt.suptitle(f'Dataset Sparsity & Interaction Metrics - {name}', 
                fontsize=14, fontweight='bold', y=0.98)
    plt.tight_layout()
    plt.show()
    
    # numeric distributions
    num_cols = [c for c, t in zip(df.columns, df.dtypes) if t.is_numeric()]
    if not num_cols:
        return

    n = len(num_cols)
    plt.figure(figsize=(3 * n, 4))
    for i, col in enumerate(num_cols, 1):
        plt.subplot(1, n, i)
        data = df[col].drop_nulls().to_numpy()
        sns.histplot(data, bins=20, kde=True, color="skyblue")
        plt.title(col)
    plt.suptitle(f"Numeric Feature Distributions - {name}", y=1.02)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### eda_ratings

# %%
def eda_ratings(df: pl.DataFrame, name: str = "dataset", show_plots: bool = True):
    if "rating" not in df.columns:
        logger.log_warning(f"[Ratings] {name} | no 'rating' column found")
        return

    s = df["rating"].drop_nulls().cast(pl.Float64)
    total = s.len() or 0
    mean_val = s.mean() if total else float("nan")
    median_val = s.median() if total else float("nan")
    mode_vals = s.mode()
    mode_val = mode_vals[0] if mode_vals.len() else None

    pos = (s.filter(s >= 4).len() / total * 100) if total else 0.0
    neu = (s.filter(s == 3).len() / total * 100) if total else 0.0
    neg = (s.filter(s <= 2).len() / total * 100) if total else 0.0

    logger.log_info(f"[Ratings] {name} | mean={mean_val:.2f}, median={median_val:.2f}, mode={mode_val} | pos={pos:.1f}%, neu={neu:.1f}%, neg={neg:.1f}%")

    if show_plots:
        counts = df.group_by("rating").agg(pl.len().alias("count")).sort("rating")
        plt.figure(figsize=(7, 4))
        sns.barplot(x=counts["rating"].to_numpy(), y=counts["count"].to_numpy(), color="skyblue")
        plt.title(f"Rating Distribution - {name}")
        plt.xlabel("Rating")
        plt.ylabel("Count")
        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### eda_users

# %%
def eda_users(df: pl.DataFrame, name: str = "dataset", show_plots: bool = False):
    user_counts = df.group_by("user_id").agg(pl.len().alias("count")).sort("count", descending=True)
    if user_counts.height == 0:
        logger.log_warning(f"[Users] {name} | No user data available")
        return

    n_users = user_counts.height
    avg_cnt = float(user_counts["count"].mean())
    med_cnt = int(user_counts["count"].median())
    max_cnt = int(user_counts["count"].max()) if user_counts["count"].max() is not None else 0
    logger.log_info(f"[Users] {name} | unique_users={n_users:,} | avg_ratings_per_user={avg_cnt:.2f} | median={med_cnt} | max={max_cnt}")

    if show_plots:
        plt.figure(figsize=(7, 4))
        sns.histplot(user_counts["count"].to_numpy(), bins=1500, color="steelblue")
        plt.title(f"#Ratings per User - {name}")
        plt.xlabel("#Ratings per User")
        plt.ylabel("Frequency")
        plt.xlim(0, min(50, max_cnt + 1))
        plt.tight_layout()
        plt.show()

    # Prepare bins and labels (ensure sensible max)
    max_cnt = max(1, max_cnt)
    bins = np.array([0, 1, 2, 3, 5, 10, 20, 50, max(51, max_cnt + 1)])
    labels = ["0–1", "1–2", "2–3", "3–5", "5–10", "10–20", "20–50", f"50–{max_cnt}"]

    counts = user_counts["count"].to_numpy()
    hist, _ = np.histogram(counts, bins=bins)
    binned = pl.DataFrame({"bin": labels, "users": hist}).with_columns(
        (pl.col("users") / n_users * 100).round(4).alias("share_pct")
    )
    logger.log_info(f"[Users][Bins] {name}\n{binned}")
    logger.log_info(f"[Users][Bins] {name} | Total users binned: {int(binned['users'].sum()):,} (expected: {n_users:,}) | Total share_pct: {float(binned['share_pct'].sum()):.2f}%")

    # if show_plots:
    plt.figure(figsize=(9, 4))
    sns.barplot(x=binned["bin"], y=binned["users"], color="steelblue")
    plt.title(f"Users by Activity Bins - {name}")
    plt.xlabel("#Ratings per User (bins)")
    plt.ylabel("#Users")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    top10 = user_counts.head(10)
    logger.log_info(f"[Users][Top10] {name}\n{top10}")
    # if show_plots and top10.height:
    plt.figure(figsize=(8, 5))
    sns.barplot(x=top10["count"], y=top10["user_id"], palette="viridis", hue=top10["count"], dodge=False, legend=False)
    plt.title(f"Top 10 Users by #Ratings - {name}")
    plt.xlabel("#Ratings")
    plt.ylabel("User ID")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### eda_items

# %%
def eda_items(df: pl.DataFrame, name: str = "dataset", show_plots: bool = True):
    item_counts = df.group_by("parent_asin").agg(pl.len().alias("count")).sort("count", descending=True)
    if item_counts.height == 0:
        logger.log_warning(f"[Items] {name} | No item data available")
        return

    n_items = item_counts.height
    avg_cnt = float(item_counts["count"].mean())
    med_cnt = int(item_counts["count"].median())
    max_cnt = int(item_counts["count"].max() or 0)
    logger.log_info(f"[Items] {name} | unique_items={n_items:,} | avg_reviews/item={avg_cnt:.2f} | median={med_cnt} | max={max_cnt}")

    if show_plots:
        plt.figure(figsize=(7, 4))
        sns.histplot(item_counts["count"].to_numpy(), bins=200, log_scale=(True, False), color="seagreen")
        plt.xscale("log")
        plt.title(f"#Ratings per Item - {name}")
        plt.xlabel("#Ratings per Item (log scale)")
        plt.ylabel("Frequency")
        plt.tight_layout()
        plt.show()

    top10 = item_counts.head(10)
    logger.log_info(f"[Items][Top10] {name}\n{top10}")

    if show_plots and top10.height:
        plt.figure(figsize=(8, 5))
        sns.barplot(x=top10["count"], y=top10["parent_asin"], palette="viridis", hue=top10["count"], dodge=False, legend=False)
        plt.title(f"Top 10 Items by #Ratings - {name}")
        plt.xlabel("#Ratings")
        plt.ylabel("Item ID")
        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### eda_time

# %%
# def _timestamp_series(df: pl.DataFrame) -> pl.Series:
#     ts = df["timestamp"].cast(pl.Int64)
#     ratio = (ts > 10**12).fill_null(False).mean() or 0.0
#     unit = "ms" if ratio > 0.5 else "s"
#     return pl.from_epoch(ts, time_unit=unit).alias("__dt")

# def eda_time(df: pl.DataFrame, name: str = "dataset", show_plots: bool = True):
#     if "timestamp" not in df.columns:
#         logger.log_warning(f"[Time] {name} | no 'timestamp' column found")
#         return

#     dt = _timestamp_series(df)
#     if dt.null_count() == df.height:
#         logger.log_info(f"[Time] {name} | no valid timestamps")
#         return

#     tmp = df.with_columns(dt)
#     counts_m = tmp.group_by(pl.col("__dt").dt.truncate("1mo")).agg(pl.len().alias("count")).sort("__dt")
#     counts_y = tmp.group_by(pl.col("__dt").dt.year()).agg(pl.len().alias("count")).sort("__dt")

#     logger.log_info(f"[Time] {name} | span={dt.min()} → {dt.max()} | months={counts_m.height}, years={counts_y.height}")

#     if show_plots:
#         plt.figure(figsize=(10, 4))
#         sns.lineplot(x=counts_m["__dt"], y=counts_m["count"], marker="o")
#         plt.title(f"Reviews per Month - {name}"); plt.xlabel("Month"); plt.ylabel("#Reviews"); plt.tight_layout(); plt.show()

#         plt.figure(figsize=(7, 4))
#         sns.barplot(x=counts_y["__dt"], y=counts_y["count"], color="skyblue")
#         plt.title(f"Reviews per Year - {name}"); plt.xlabel("Year"); plt.ylabel("#Reviews"); plt.xticks(rotation=45); plt.tight_layout(); plt.show()

#     if "user_id" in tmp.columns:
#         user_month = (
#             tmp.group_by([pl.col("__dt").dt.truncate("1mo"), "user_id"])
#                .agg(pl.len().alias("count"))
#                .group_by("__dt")
#                .agg(pl.col("count").mean())
#         )
#         if show_plots and user_month.height:
#             plt.figure(figsize=(10, 4))
#             sns.lineplot(x=user_month["__dt"], y=user_month["count"], marker="o", color="green")
#             plt.title(f"Average Reviews per User per Month - {name}"); plt.xlabel("Month"); plt.ylabel("Avg Reviews/User"); plt.tight_layout(); plt.show()

#     if "parent_asin" in tmp.columns:
#         item_month = (
#             tmp.group_by([pl.col("__dt").dt.truncate("1mo"), "parent_asin"])
#                .agg(pl.len().alias("count"))
#                .group_by("__dt")
#                .agg(pl.col("count").mean())
#         )
#         if show_plots and item_month.height:
#             plt.figure(figsize=(10, 4))
#             sns.lineplot(x=item_month["__dt"], y=item_month["count"], marker="o", color="purple")
#             plt.title(f"Average Reviews per Item per Month - {name}"); plt.xlabel("Month"); plt.ylabel("Avg Reviews/Item"); plt.tight_layout(); plt.show()

from scipy.ndimage import uniform_filter1d

def _timestamp_series(df: pl.DataFrame) -> pl.Series:
    ts = df["timestamp"].cast(pl.Int64)
    ratio = (ts > 10**12).fill_null(False).mean() or 0.0
    unit = "ms" if ratio > 0.5 else "s"
    return pl.from_epoch(ts, time_unit=unit).alias("__dt")

def eda_time(df: pl.DataFrame, name: str = "dataset", show_plots: bool = True):
    if "timestamp" not in df.columns:
        logger.log_warning(f"[Time] {name} | no 'timestamp' column found")
        return

    dt = _timestamp_series(df)
    if dt.null_count() == df.height:
        logger.log_info(f"[Time] {name} | no valid timestamps")
        return

    tmp = df.with_columns(dt)
    counts_m = tmp.group_by(pl.col("__dt").dt.truncate("1mo")).agg(pl.len().alias("count")).sort("__dt")
    counts_y = tmp.group_by(pl.col("__dt").dt.year()).agg(pl.len().alias("count")).sort("__dt")

    logger.log_info(f"[Time] {name} | span={dt.min()} → {dt.max()} | months={counts_m.height}, years={counts_y.height}")

    if show_plots:
        plt.figure(figsize=(10, 4))
        sns.lineplot(x=counts_m["__dt"], y=counts_m["count"], marker="o")
        if len(counts_m) >= 30:
            ma30 = uniform_filter1d(counts_m["count"].to_numpy(), size=30, mode='nearest')
            plt.plot(counts_m["__dt"], ma30, color="red", linewidth=2, label="30-day MA")
            plt.legend()
        plt.title(f"Reviews per Month - {name}"); plt.xlabel("Month"); plt.ylabel("#Reviews"); plt.tight_layout(); plt.show()

        plt.figure(figsize=(7, 4))
        sns.barplot(x=counts_y["__dt"], y=counts_y["count"], color="skyblue")
        plt.title(f"Reviews per Year - {name}"); plt.xlabel("Year"); plt.ylabel("#Reviews"); plt.xticks(rotation=45); plt.tight_layout(); plt.show()

    if "user_id" in tmp.columns:
        user_month = (
            tmp.group_by([pl.col("__dt").dt.truncate("1mo"), "user_id"])
               .agg(pl.len().alias("count"))
               .group_by("__dt")
               .agg(pl.col("count").mean())
               .sort("__dt")
        )
        if show_plots and user_month.height:
            plt.figure(figsize=(10, 4))
            sns.lineplot(x=user_month["__dt"], y=user_month["count"], marker="o", color="green")
            if len(user_month) >= 30:
                ma30 = uniform_filter1d(user_month["count"].to_numpy(), size=30, mode='nearest')
                plt.plot(user_month["__dt"], ma30, color="red", linewidth=2, label="30-day MA")
                plt.legend()
            plt.title(f"Average Reviews per User per Month - {name}"); plt.xlabel("Month"); plt.ylabel("Avg Reviews/User"); plt.tight_layout(); plt.show()

    if "parent_asin" in tmp.columns:
        item_month = (
            tmp.group_by([pl.col("__dt").dt.truncate("1mo"), "parent_asin"])
               .agg(pl.len().alias("count"))
               .group_by("__dt")
               .agg(pl.col("count").mean())
               .sort("__dt")
        )
        if show_plots and item_month.height:
            plt.figure(figsize=(10, 4))
            sns.lineplot(x=item_month["__dt"], y=item_month["count"], marker="o", color="purple")
            if len(item_month) >= 30:
                ma30 = uniform_filter1d(item_month["count"].to_numpy(), size=30, mode='nearest')
                plt.plot(item_month["__dt"], ma30, color="red", linewidth=2, label="30-day MA")
                plt.legend()
            plt.title(f"Average Reviews per Item per Month - {name}"); plt.xlabel("Month"); plt.ylabel("Avg Reviews/Item"); plt.tight_layout(); plt.show()

# %% [markdown]
# #### eda_history

# %%
def eda_history(df: pl.DataFrame, name: str = "dataset", show_plots: bool = True):
    if "history" not in df.columns:
        logger.log_warning(f"[History] {name} | no 'history' column found")
        return

    h = df["history"].cast(pl.Utf8).str.strip_chars().str.split(" ").list.len().fill_null(0).cast(pl.Int64).to_numpy()
    if h.size == 0 or h.sum() == 0:
        logger.log_info(f"[History] {name} | histories present but all lengths=0")
        return h

    mean_val, med_val, max_val = np.mean(h), np.median(h), int(h.max())
    p90, p99 = np.percentile(h, 90), np.percentile(h, 99)
    nonzero_pct = (h > 0).mean() * 100

    logger.log_info(f"[History] {name} | mean={mean_val:.2f}, median={int(med_val)}, max={max_val}, p90={p90:.1f}, p99={p99:.1f}, nonzero%={nonzero_pct:.1f}")

    if show_plots:
        pos = h[h > 0]
        if pos.size:
            plt.figure(figsize=(7, 4))
            plt.hist(pos, bins=np.logspace(0, np.log10(max(1, max_val)), 40), color="seagreen")
            plt.xscale("log")
            plt.title(f"History Length Distribution (log-x) - {name}")
            plt.xlabel("History Length")
            plt.ylabel("Frequency")
            plt.tight_layout()
            plt.show()

    return h

# %% [markdown]
# #### runners

# %%
def run_eda_core0(df0: pl.DataFrame, name_suffix=""):
    name = f"0-core{name_suffix}"
    logger.log_info("=== Light EDA for 0-core dataset===")
    eda_basic(df0, name)
    eda_ratings(df0, name)

def run_eda_core5(df5: pl.DataFrame, name_suffix=""):
    name = f"5-core{name_suffix}"
    logger.log_info("=== Full EDA for 5-core dataset===")
    eda_basic(df5, name)
    eda_ratings(df5, name)
    eda_users(df5, name)
    eda_items(df5, name)
    eda_time(df5, name)
    eda_history(df5, name)

# %% [markdown]
# #### Batch runners for list categories

# %%
def run_for_categories(categories=None, run_core0=True, run_core5=True):
    """Loop over categories and run EDA (defaults to VALID_CATEGORIES)."""
    if categories is None:
        categories = VALID_CATEGORIES
    logger.log_info(f"### EDA for categories: {categories} ###")

    cores = []
    if run_core0: cores.append(("0core", run_eda_core0))
    if run_core5: cores.append(("5core", run_eda_core5))

    for cat in categories:
        logger.log_info(f"--- Category: {cat} ---")
        for core_name, eda_fn in cores:
            try:
                df = load_core_dataset(core_name, cat)
                eda_fn(df, name_suffix=f" | {cat}")
            except Exception as e:
                logger.log_warning(f"[Skip {core_name}] {cat}: {e}")
            finally:
                if "df" in locals():
                    try:
                        del df
                        gc.collect()
                    except Exception:
                        pass

# %% [markdown]
# ### Task: Unit test

# %%
run_for_categories(categories=VALID_CATEGORIES)
# Out:
# 2025-11-03 15:35:12,753 - INFO - ### EDA for categories: ['Electronics', 'Beauty_and_Personal_Care', 'Sports_and_Outdoors'] ###
# 2025-11-03 15:35:12,754 - INFO - --- Category: Electronics ---
# 2025-11-03 15:35:12,755 - WARNING - [Skip 0core] Electronics: Invalid core '0core'. Must be one of: ['5core']
# 2025-11-03 15:35:12,755 - INFO - [Loader] core=5core, category=Electronics, splits=['train']
# 2025-11-03 15:35:12,756 - INFO - [Loader] Reading: Electronics.5core.train.big.parquet
# 2025-11-03 15:35:12,765 - INFO - [Loader] Loaded train: rows=51914, cols=4
# 2025-11-03 15:35:12,769 - INFO - [Loader] Done core=5core, category=Electronics | rows=51914, cols=4 | users=32556 | items=28 | density=0.056950
# 2025-11-03 15:35:12,770 - INFO - === Full EDA for 5-core dataset===
# 2025-11-03 15:35:12,773 - INFO - [Basic] 5-core | Electronics | users=32,556 | items=28 | ratings=51,914
# 2025-11-03 15:35:12,777 - INFO - [Basic] 5-core | Electronics | density=0.056950 | sparsity=94.304978%
# 2025-11-03 15:35:12,779 - INFO - [Basic] 5-core | Electronics | avg_items/user=1.59 | avg_users/item=1854.07
# 2025-11-03 15:35:12,780 - INFO - [Basic][Data types]
# user_id: String
# parent_asin: String
# rating: Float64
# timestamp: Int64
# 2025-11-03 15:35:12,832 - INFO - [Basic][Missing values]
# shape: (1, 4)
# ┌─────────┬─────────────┬────────┬───────────┐
# │ user_id ┆ parent_asin ┆ rating ┆ timestamp │
# │ ---     ┆ ---         ┆ ---    ┆ ---       │
# │ u32     ┆ u32         ┆ u32    ┆ u32       │
# ╞═════════╪═════════════╪════════╪═══════════╡
# │ 0       ┆ 0           ┆ 0      ┆ 0         │
# └─────────┴─────────────┴────────┴───────────┘
# 2025-11-03 15:35:12,837 - INFO - [Basic][Duplicate rows] 0
# 2025-11-03 15:35:13,196 - INFO - [Ratings] 5-core | Electronics | mean=4.50, median=5.00, mode=5.0 | pos=87.5%, neu=5.3%, neg=7.2%
# 2025-11-03 15:35:13,255 - INFO - [Users] 5-core | Electronics | unique_users=32,556 | avg_ratings_per_user=1.59 | median=1 | max=11
# 2025-11-03 15:35:13,256 - INFO - [Users][Bins] 5-core | Electronics
# shape: (8, 3)
# ┌───────┬───────┬───────────┐
# │ bin   ┆ users ┆ share_pct │
# │ ---   ┆ ---   ┆ ---       │
# │ str   ┆ i64   ┆ f64       │
# ╞═══════╪═══════╪═══════════╡
# │ 0–1   ┆ 0     ┆ 0.0       │
# │ 1–2   ┆ 19738 ┆ 60.6278   │
# │ 2–3   ┆ 8397  ┆ 25.7925   │
# │ 3–5   ┆ 3980  ┆ 12.2251   │
# │ 5–10  ┆ 437   ┆ 1.3423    │
# │ 10–20 ┆ 4     ┆ 0.0123    │
# │ 20–50 ┆ 0     ┆ 0.0       │
# │ 50–11 ┆ 0     ┆ 0.0       │
# └───────┴───────┴───────────┘
# 2025-11-03 15:35:13,257 - INFO - [Users][Bins] 5-core | Electronics | Total users binned: 32,556 (expected: 32,556) | Total share_pct: 100.00%
# 2025-11-03 15:35:13,318 - INFO - [Users][Top10] 5-core | Electronics
# shape: (10, 2)
# ┌──────────────────────────────┬───────┐
# │ user_id                      ┆ count │
# │ ---                          ┆ ---   │
# │ str                          ┆ u32   │
# ╞══════════════════════════════╪═══════╡
# │ AHL3TEVTN5EZI7TWZRLAO4EULXKA ┆ 11    │
# │ AGTVZ7ZSDMTEDLMJGZRC7RFJNDWQ ┆ 11    │
# │ AHZ6OIF3GOKCZC7EVEZUAGZ4RIOQ ┆ 10    │
# │ AHX7ER6ODLRXMZF3WLEFJVRUJUXQ ┆ 10    │
# │ AE6XKJXWVFAVOYGQMO3YIZ6C3BFQ ┆ 9     │
# │ AFGXEL3M4QBIWLICQZRGJKBJGZKA ┆ 9     │
# │ AGMFVZKQ3QSW4NMW6WFIW2IZFRMQ ┆ 8     │
# │ AGZ5RFKC7DY6TKLNNP3QLJFKFHBQ ┆ 8     │
# │ AEKC6ZMOD2FGT2JR4FDL3NBPOEBQ ┆ 8     │
# │ AEMKPZ4U2RBZWOXWQX5NSY6WBB3A ┆ 8     │
# └──────────────────────────────┴───────┘
# 2025-11-03 15:35:13,412 - INFO - [Items] 5-core | Electronics | unique_items=28 | avg_reviews/item=1854.07 | median=1490 | max=4090
# 2025-11-03 15:35:13,560 - INFO - [Items][Top10] 5-core | Electronics
# shape: (10, 2)
# ┌─────────────┬───────┐
# │ parent_asin ┆ count │
# │ ---         ┆ ---   │
# │ str         ┆ u32   │
# ╞═════════════╪═══════╡
# │ B01K8B8YA8  ┆ 4090  │
# │ B011BRUOMO  ┆ 3474  │
# │ B075X8471B  ┆ 3374  │
# │ B07GZFM1ZM  ┆ 2638  │
# │ B0BGNG1294  ┆ 2616  │
# │ B07S764D9V  ┆ 2442  │
# │ B010BWYDYA  ┆ 2195  │
# │ B008J0Z9TA  ┆ 2148  │
# │ B07P9V8GSH  ┆ 2086  │
# │ B083TH1B45  ┆ 1738  │
# └─────────────┴───────┘
# 2025-11-03 15:35:13,645 - INFO - [Time] 5-core | Electronics | span=2007-11-19 06:28:57 → 2023-05-04 18:32:42.175000 | months=181, years=17
# 2025-11-03 15:35:14,236 - WARNING - [History] 5-core | Electronics | no 'history' column found
# 2025-11-03 15:35:14,404 - INFO - --- Category: Beauty_and_Personal_Care ---
# 2025-11-03 15:35:14,404 - WARNING - [Skip 0core] Beauty_and_Personal_Care: Invalid core '0core'. Must be one of: ['5core']
# 2025-11-03 15:35:14,405 - INFO - [Loader] core=5core, category=Beauty_and_Personal_Care, splits=['train']
# 2025-11-03 15:35:14,406 - INFO - [Loader] Reading: Beauty_and_Personal_Care.5core.train.big.parquet
# 2025-11-03 15:35:14,410 - INFO - [Loader] Loaded train: rows=22143, cols=4
# 2025-11-03 15:35:14,411 - INFO - [Loader] Done core=5core, category=Beauty_and_Personal_Care | rows=22143, cols=4 | users=16821 | items=23 | density=0.057234
# 2025-11-03 15:35:14,411 - INFO - === Full EDA for 5-core dataset===
# 2025-11-03 15:35:14,413 - INFO - [Basic] 5-core | Beauty_and_Personal_Care | users=16,821 | items=23 | ratings=22,143
# 2025-11-03 15:35:14,413 - INFO - [Basic] 5-core | Beauty_and_Personal_Care | density=0.057234 | sparsity=94.276564%
# 2025-11-03 15:35:14,413 - INFO - [Basic] 5-core | Beauty_and_Personal_Care | avg_items/user=1.32 | avg_users/item=962.74
# 2025-11-03 15:35:14,414 - INFO - [Basic][Data types]
# user_id: String
# parent_asin: String
# rating: Float64
# timestamp: Int64
# 2025-11-03 15:35:14,414 - INFO - [Basic][Missing values]
# shape: (1, 4)
# ┌─────────┬─────────────┬────────┬───────────┐
# │ user_id ┆ parent_asin ┆ rating ┆ timestamp │
# │ ---     ┆ ---         ┆ ---    ┆ ---       │
# │ u32     ┆ u32         ┆ u32    ┆ u32       │
# ╞═════════╪═════════════╪════════╪═══════════╡
# │ 0       ┆ 0           ┆ 0      ┆ 0         │
# └─────────┴─────────────┴────────┴───────────┘
# 2025-11-03 15:35:14,416 - INFO - [Basic][Duplicate rows] 0
# 2025-11-03 15:35:14,822 - INFO - [Ratings] 5-core | Beauty_and_Personal_Care | mean=4.27, median=5.00, mode=5.0 | pos=79.3%, neu=9.1%, neg=11.6%
# 2025-11-03 15:35:14,949 - INFO - [Users] 5-core | Beauty_and_Personal_Care | unique_users=16,821 | avg_ratings_per_user=1.32 | median=1 | max=8
# 2025-11-03 15:35:14,950 - INFO - [Users][Bins] 5-core | Beauty_and_Personal_Care
# shape: (8, 3)
# ┌───────┬───────┬───────────┐
# │ bin   ┆ users ┆ share_pct │
# │ ---   ┆ ---   ┆ ---       │
# │ str   ┆ i64   ┆ f64       │
# ╞═══════╪═══════╪═══════════╡
# │ 0–1   ┆ 0     ┆ 0.0       │
# │ 1–2   ┆ 12845 ┆ 76.3629   │
# │ 2–3   ┆ 3021  ┆ 17.9597   │
# │ 3–5   ┆ 876   ┆ 5.2078    │
# │ 5–10  ┆ 79    ┆ 0.4697    │
# │ 10–20 ┆ 0     ┆ 0.0       │
# │ 20–50 ┆ 0     ┆ 0.0       │
# │ 50–8  ┆ 0     ┆ 0.0       │
# └───────┴───────┴───────────┘
# 2025-11-03 15:35:14,950 - INFO - [Users][Bins] 5-core | Beauty_and_Personal_Care | Total users binned: 16,821 (expected: 16,821) | Total share_pct: 100.00%
# 2025-11-03 15:35:15,029 - INFO - [Users][Top10] 5-core | Beauty_and_Personal_Care
# shape: (10, 2)
# ┌──────────────────────────────┬───────┐
# │ user_id                      ┆ count │
# │ ---                          ┆ ---   │
# │ str                          ┆ u32   │
# ╞══════════════════════════════╪═══════╡
# │ AFGRAUIXGHWO224SV5YN3TNEUMJA ┆ 8     │
# │ AHXC2I6S4EPTLZVREO7PNT5RXMCQ ┆ 8     │
# │ AERRWYU2TFQ3Z2INNXKAXZFZUBTQ ┆ 8     │
# │ AEFUTN7CZWP6FSJGTW4IRF7U35QA ┆ 8     │
# │ AGPC7CWRQPMNQFXWLYJYQYF7DCQA ┆ 8     │
# │ AHGR64B35B4FBB5C7CNQ47BWJARQ ┆ 7     │
# │ AFHRPCWEWPAAA2ZVLDTJHDIFR3VA ┆ 7     │
# │ AFGQCKYIGY447XF2ZEQO7GOHPJVA ┆ 7     │
# │ AFSQ4SBHGOJFYEGOO2M3DXYU6CNQ ┆ 7     │
# │ AF2VNCHWIKDNLBWNPZJQQ5IFVPAQ ┆ 7     │
# └──────────────────────────────┴───────┘
# 2025-11-03 15:35:15,183 - INFO - [Items] 5-core | Beauty_and_Personal_Care | unique_items=23 | avg_reviews/item=962.74 | median=903 | max=1715
# 2025-11-03 15:35:15,364 - INFO - [Items][Top10] 5-core | Beauty_and_Personal_Care
# shape: (10, 2)
# ┌─────────────┬───────┐
# │ parent_asin ┆ count │
# │ ---         ┆ ---   │
# │ str         ┆ u32   │
# ╞═════════════╪═══════╡
# │ B07YT2VKTG  ┆ 1715  │
# │ B0BVGHXZJ1  ┆ 1414  │
# │ B0C4K2HYLZ  ┆ 1135  │
# │ B073WVCH57  ┆ 1105  │
# │ B0BVW6XYNZ  ┆ 1066  │
# │ B0BS71PXPX  ┆ 999   │
# │ B0B6QVGZ4X  ┆ 989   │
# │ B09GN3GC8G  ┆ 969   │
# │ B09GN3GC8C  ┆ 958   │
# │ B0BP5GSPLL  ┆ 954   │
# └─────────────┴───────┘
# 2025-11-03 15:35:15,523 - INFO - [Time] 5-core | Beauty_and_Personal_Care | span=2008-12-06 05:10:47 → 2023-08-06 21:10:43.795000 | months=152, years=16
# 2025-11-03 15:35:16,026 - WARNING - [History] 5-core | Beauty_and_Personal_Care | no 'history' column found
# 2025-11-03 15:35:16,180 - INFO - --- Category: Sports_and_Outdoors ---
# 2025-11-03 15:35:16,180 - WARNING - [Skip 0core] Sports_and_Outdoors: Invalid core '0core'. Must be one of: ['5core']
# 2025-11-03 15:35:16,180 - INFO - [Loader] core=5core, category=Sports_and_Outdoors, splits=['train']
# 2025-11-03 15:35:16,181 - INFO - [Loader] Reading: Sports_and_Outdoors.5core.train.big.parquet
# 2025-11-03 15:35:16,184 - INFO - [Loader] Loaded train: rows=14534, cols=4
# 2025-11-03 15:35:16,186 - INFO - [Loader] Done core=5core, category=Sports_and_Outdoors | rows=14534, cols=4 | users=11776 | items=23 | density=0.053661
# 2025-11-03 15:35:16,186 - INFO - === Full EDA for 5-core dataset===
# 2025-11-03 15:35:16,187 - INFO - [Basic] 5-core | Sports_and_Outdoors | users=11,776 | items=23 | ratings=14,534
# 2025-11-03 15:35:16,187 - INFO - [Basic] 5-core | Sports_and_Outdoors | density=0.053661 | sparsity=94.633891%
# 2025-11-03 15:35:16,187 - INFO - [Basic] 5-core | Sports_and_Outdoors | avg_items/user=1.23 | avg_users/item=631.91
# 2025-11-03 15:35:16,188 - INFO - [Basic][Data types]
# user_id: String
# parent_asin: String
# rating: Float64
# timestamp: Int64
# 2025-11-03 15:35:16,188 - INFO - [Basic][Missing values]
# shape: (1, 4)
# ┌─────────┬─────────────┬────────┬───────────┐
# │ user_id ┆ parent_asin ┆ rating ┆ timestamp │
# │ ---     ┆ ---         ┆ ---    ┆ ---       │
# │ u32     ┆ u32         ┆ u32    ┆ u32       │
# ╞═════════╪═════════════╪════════╪═══════════╡
# │ 0       ┆ 0           ┆ 0      ┆ 0         │
# └─────────┴─────────────┴────────┴───────────┘
# 2025-11-03 15:35:16,189 - INFO - [Basic][Duplicate rows] 0
# 2025-11-03 15:35:16,465 - INFO - [Ratings] 5-core | Sports_and_Outdoors | mean=4.52, median=5.00, mode=5.0 | pos=88.4%, neu=5.9%, neg=5.7%
# 2025-11-03 15:35:16,594 - INFO - [Users] 5-core | Sports_and_Outdoors | unique_users=11,776 | avg_ratings_per_user=1.23 | median=1 | max=7
# 2025-11-03 15:35:16,596 - INFO - [Users][Bins] 5-core | Sports_and_Outdoors
# shape: (8, 3)
# ┌───────┬───────┬───────────┐
# │ bin   ┆ users ┆ share_pct │
# │ ---   ┆ ---   ┆ ---       │
# │ str   ┆ i64   ┆ f64       │
# ╞═══════╪═══════╪═══════════╡
# │ 0–1   ┆ 0     ┆ 0.0       │
# │ 1–2   ┆ 9642  ┆ 81.8784   │
# │ 2–3   ┆ 1670  ┆ 14.1814   │
# │ 3–5   ┆ 433   ┆ 3.677     │
# │ 5–10  ┆ 31    ┆ 0.2632    │
# │ 10–20 ┆ 0     ┆ 0.0       │
# │ 20–50 ┆ 0     ┆ 0.0       │
# │ 50–7  ┆ 0     ┆ 0.0       │
# └───────┴───────┴───────────┘
# 2025-11-03 15:35:16,596 - INFO - [Users][Bins] 5-core | Sports_and_Outdoors | Total users binned: 11,776 (expected: 11,776) | Total share_pct: 100.00%
# 2025-11-03 15:35:16,674 - INFO - [Users][Top10] 5-core | Sports_and_Outdoors
# shape: (10, 2)
# ┌──────────────────────────────┬───────┐
# │ user_id                      ┆ count │
# │ ---                          ┆ ---   │
# │ str                          ┆ u32   │
# ╞══════════════════════════════╪═══════╡
# │ AEKD33TQ57VSFWINKUM3VAS3ZEFQ ┆ 7     │
# │ AEZABEV7CXSQMDDKLGI25KGTVYOA ┆ 7     │
# │ AE4RBEK5QUQ3PIKCUU2O2YZCCQ5Q ┆ 7     │
# │ AERWHJFH5YSDIZCPCPYTKBSHDWBA ┆ 6     │
# │ AFF2UM6YXXZ3PPCKWUPFPIHQNW3A ┆ 6     │
# │ AG5YXRKQ6J6VCARHEKOXQE5Y2EAQ ┆ 6     │
# │ AGY3K7CA27UJCTOGZEO2WW6DCUWA ┆ 6     │
# │ AEA64TVHGKB3T5UHJGBBPAM5BBSQ ┆ 6     │
# │ AFH5DN432VT3WWJ7TZ3AFQLL4ISA ┆ 6     │
# │ AF4S4UQSLI7V4LHTS5YE54KOYHXQ ┆ 5     │
# └──────────────────────────────┴───────┘
# 2025-11-03 15:35:16,835 - INFO - [Items] 5-core | Sports_and_Outdoors | unique_items=23 | avg_reviews/item=631.91 | median=541 | max=1455
# 2025-11-03 15:35:17,021 - INFO - [Items][Top10] 5-core | Sports_and_Outdoors
# shape: (10, 2)
# ┌─────────────┬───────┐
# │ parent_asin ┆ count │
# │ ---         ┆ ---   │
# │ str         ┆ u32   │
# ╞═════════════╪═══════╡
# │ B0BBFB48YQ  ┆ 1455  │
# │ B0BX5QFWQN  ┆ 1357  │
# │ B08HWP19XK  ┆ 1044  │
# │ B0BKFGDBBM  ┆ 724   │
# │ B00D3WV3VC  ┆ 669   │
# │ B00C6OUDX2  ┆ 650   │
# │ B0BX4ZDSTQ  ┆ 616   │
# │ B00NWXLQD2  ┆ 603   │
# │ B0BGWL9WJF  ┆ 583   │
# │ B0BYQQRXV8  ┆ 559   │
# └─────────────┴───────┘
# 2025-11-03 15:35:17,183 - INFO - [Time] 5-core | Sports_and_Outdoors | span=2008-04-07 04:49:16 → 2023-08-26 19:27:02.924000 | months=167, years=16
# 2025-11-03 15:35:17,753 - WARNING - [History] 5-core | Sports_and_Outdoors | no 'history' column found
